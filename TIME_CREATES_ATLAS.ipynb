# %% [markdown]
# # The intro

# %% [markdown]
# # The atom of mathematics and Leibniz  monads
#
#
# # The Energy/Symmetry relationship in the core of basic mathematical objects $E=mc^2$

# %% [markdown]
# ## Wormhole_0
#
# ### Flower_0
#
# #### xyz x4
# A = ( u,  v,  w)
# B = ( u, –v,  w)
# C = (–u,  v,  w)
# D = (–u, –v,  w)
#
# #### yxz x4
# E = ( v,  u,  w)
# F = ( v, –u,  w)
# G = (–v,  u,  w)
# H = (–v, –u,  w)
#
# ### Flower_1
#
# #### xy(–z) x4
# I  = ( u,  v, –w)
# J  = ( u, –v, –w)
# K  = (–u,  v, –w)
# L  = (–u, –v, –w)
#
# #### yx(–z) x4
# M = ( v,  u, –w)
# N = ( v, –u, –w)
# O = (–v,  u, –w)
# P = (–v, –u, –w)
#
# ---
#
# ## Wormhole_1
#
# ### Flower_2
#
# #### zxy x4
# Q = ( w,  u,  v)
# R = ( w,  u, –v)
# S = ( w, –u,  v)
# T = ( w, –u, –v)
#
# #### zyx x4
# U = ( w,  v,  u)
# V = ( w,  v, –u)
# W = ( w, –v,  u)
# X = ( w, –v, –u)
#
# ### Flower_3
#
# For these sets we “flip” the z-coordinate so that –w is now held constant.
#
# #### (–z)xy x4
# α (alpha) = (–w,  u,  v)
# β (beta)  = (–w,  u, –v)
# γ (gamma) = (–w, –u,  v)
# δ (delta) = (–w, –u, –v)
#
# #### (–z)yx x4
# ε (epsilon) = (–w,  v,  u)
# ζ (zeta)    = (–w,  v, –u)
# η (eta)     = (–w, –v,  u)
# θ (theta)   = (–w, –v, –u)
#
# ---
#
# ## Wormhole_2
#
# ### Flower_4
#
# Here the ordering is “xzy” or “yzx” so that w appears in the middle (and is held constant).
#
# #### xzy x4
# ι (iota)   = ( u,  w,  v)
# κ (kappa)  = ( u,  w, –v)
# λ (lambda) = (–u,  w,  v)
# μ (mu)     = (–u,  w, –v)
#
# #### yzx x4
# ν (nu)      = ( v,  w,  u)
# ξ (xi)      = ( v,  w, –u)
# ο (omicron) = (–v,  w,  u)
# π (pi)      = (–v,  w, –u)
#
# ### Flower_5
#
# For these two sets the invariant coordinate is –w (with w flipped).
#
# #### x(–z)y x4
# ρ (rho)     = ( u, –w,  v)
# σ (sigma)   = ( u, –w, –v)
# τ (tau)     = (–u, –w,  v)
# υ (upsilon) = (–u, –w, –v)
#
# #### y(–z)x x4
# φ (phi)     = ( v, –w,  u)
# χ (chi)     = ( v, –w, –u)
# ψ (psi)     = (–v, –w,  u)
# ω (omega)   = (–v, –w, –u)

# %%
from atom import *

# %%
def main(video_file="file.mpg"):
    # Parameters for the carrier
    N = 100        # Number of points
    D = 4           # For our toy-universe: 3+1=4
    M_c = 13        # Color modulus (n mod M_c)
    
    # Compute the carrier using our formulas.
    n_array, u, v, w, gamma, alpha, beta = compute_carrier(N, D)
    
    # # To plot the Atom structure (all 48 curves) statically as scatter only:
    # plot_atom(n_array, u, v, w, gamma, M_c, plot_mode='scatter',
    #           scatter_size=7, scatter_alpha=0.5,
    #           line_alpha=0.7, line_width=2, line_cmap='hsv')
    
    # To animate the Atom structure with dynamic zoom-out, uncomment:
    animate_atom(n_array, u, v, w, gamma, M_c, plot_mode='scatter',
                 scatter_size=7, scatter_alpha=0.5,
                 line_alpha=0.7, line_width=2, line_cmap='hsv',
                 frame_interval=1000, video_file=video_file)

if __name__ == '__main__':
    main(video_file="file3.mpg")
